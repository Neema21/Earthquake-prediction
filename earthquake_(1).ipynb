# %% [markdown]
# <a href="https://colab.research.google.com/github/Neema21/Earthquake-prediction/blob/main/earthquake_(1).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import svm
from sklearn.model_selection import train_test_split
#from sklearn.cross_validation import train_test_split
from sklearn.metrics import accuracy_score

# %%
from google.colab import files
uploaded_test= files.upload()
# Out:
#      <input type="file" id="files-34c1bf4e-d0f2-49e1-92f0-7f1a1fdb3a01" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-34c1bf4e-d0f2-49e1-92f0-7f1a1fdb3a01">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data = pd.read_csv("/content/datasamlpleweka.csv")
data.head()
data
# Out:
#     Dateofwaves TimeStamp  latitude  longitude  depth  magnitude     Location
# 0    29/11/2021   17:26.5     -6.97     127.28    389        4.9  'Banda Sea'
# 1    30/11/2021   13:13.0     -5.17     129.95     10        3.7  'Banda Sea'
# 2    01/12/2021   46:14.4     -6.22     130.27    179        3.9  'Banda Sea'
# 3    01/12/2021   07:04.4     -7.16     124.71    539        4.2  'Banda Sea'
# 4    01/12/2021   18:08.7     -7.58     128.38    139        4.5  'Banda Sea'
# ..          ...       ...       ...        ...    ...        ...          ...
# 218  14/01/2021   55:16.4     -3.01     118.94     19        3.0     Sulawesi
# 219  14/01/2021   48:52.1     -2.95     118.89     11        3.9     Sulawesi
# 220  14/01/2021   41:54.1     -2.89     118.88     10        4.1     Sulawesi
# 221  14/01/2021   39:57.7     -3.03     118.95     10        4.1     Sulawesi
# 222  14/01/2021   28:20.2     -2.97     118.94     21        6.2     Sulawesi
#
# [223 rows x 7 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 223 entries, 0 to 222
# Data columns (total 7 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Dateofwaves  223 non-null    object
#  1   TimeStamp    223 non-null    object
#  2   latitude     223 non-null    float64
#  3   longitude    223 non-null    float64
#  4   depth        223 non-null    int64
#  5   magnitude    223 non-null    float64
#  6   Location     223 non-null    object
# dtypes: float64(3), int64(1), object(3)
# memory usage: 12.3+ KB

# %%
data.shape
# 0 for rows and 1 for columns
print('data has a cardinality size {}'.format(data.shape[0]) + 
      ' and dimensionality size {}'.format(data.shape[1]))
# Out:
# data has a cardinality size 223 and dimensionality size 7

# %%
data.isna().sum()
# Out:
# Dateofwaves    0
# TimeStamp      0
# latitude       0
# longitude      0
# depth          0
# magnitude      0
# Location       0
# dtype: int64

# %%
data.isna().mean()
# Out:
# Dateofwaves    0.0
# TimeStamp      0.0
# latitude       0.0
# longitude      0.0
# depth          0.0
# magnitude      0.0
# Location       0.0
# dtype: float64

# %% [markdown]
# ## **Data Visualization**

# %%
plt.figure(figsize=(10,6))
sns.heatmap(data.corr(), cmap='coolwarm', annot=True, linewidths=.1)
plt.show()

# %%
plt.figure(figsize=(10,5)) 
plt.plot(data.magnitude[:500])
plt.show()

# %%
plt.figure(figsize=(20,10)) 
plt.plot(data.magnitude[:500])
plt.show()

# %%
 #Select a subset of the data (e.g., first rows)
data = data.iloc[65:158]

# Create a line plot using the subset of data
data = plt.plot(data.Dateofwaves[:20/01/2009], data.magnitude[3.4:7.5])

# Set the x-axis label
plt.xlabel('Date of Waves')

# Set the y-axis label
plt.ylabel('Magnitude')

# Show the plot
plt.show()
# Out:
#   File "<ipython-input-77-f4179b18878b>", line 5
#     plt.plot(data.Dateofwaves[], data.magnitude[3.4:7.5])
#                               ^
# SyntaxError: invalid syntax

# %% [markdown]
# # **Splitting test and train**

# %%
import matplotlib.pyplot as plt

# %%
start_row=0
end_row=63
test_size=0.28

# %%
train_data,test_data = train_test_split(data[start_row: end_row], test_size = test_size )

# %%
classifier = svm.SVC(kernel="linear")

# %%
x = data[['Dateofwaves']]
y = data['magnitude']

# %%
x_train = []
y_train = []
x_test = []
y_test = []

# %%
x=data.iloc[:, 0].values
y=data.iloc[:, 1].values

x=x.reshape(-1,1)

# %%
x_train, x_test, y_train, y_test = train_test_split(
                      x, y, test_size=0.28, random_state=45)
...
# Out:
# Ellipsis
